# %%
from scrape_tgdd import *

# %%
# %%time
file = "url_sạc_dự_phòng.txt"
items, error_items = scrape_data(file)
# Out:
# Starting item 0 / 56->Scraping...
# Doesn't have informations of version from https://www.thegioididong.com/sac-dtdd/sac-du-phong-polymer-10000mah-khong-day-magnetic-type-c-pd-20w-xmobile-t156
# Done item 0 / 56
# Starting item 1 / 56->Scraping...
# Doesn't have informations of version from https://www.thegioididong.com/sac-dtdd/pin-polymer-10000mah-ava-plus-jp208
# Done item 1 / 56
# Starting item 2 / 56->Scraping...
# Doesn't have informations of version from https://www.thegioididong.com/sac-dtdd/pin-polymer-10000mah-ava-ds006
# Done item 2 / 56
# Starting item 3 / 56->Scraping...
# Doesn't have informations of version from https://www.thegioididong.com/sac-dtdd/pin-polymer-10000mah-type-c-ava-pb100s
# Done item 3 / 56
# Starting item 4 / 56->Scraping...
# Doesn't have informations of version from https://www.thegioididong.com/sac-dtdd/pin-polymer-10000mah-type-c-ava-pj-jp260
# Done item 4 / 56
# Starting item 5 / 56->Scraping...
# ...

# %%
# %%time
file = "url_thiết_bị_mạng.txt"
items, error_items = scrape_data(file)
# Out:
# Starting item 0 / 60->Scraping...
# Doesn't have informations of version from https://www.thegioididong.com/thiet-bi-mang/bo-phat-song-wifi-6-bang-tan-kep-asus-ax53u
# Done item 0 / 60
# Starting item 1 / 60->Scraping...
# Doesn't have informations of version from https://www.thegioididong.com/thiet-bi-mang/bo-phat-song-wifi-router-chuan-wifi-6-asus-ax1800hp-den
# Done item 1 / 60
# Starting item 2 / 60->Scraping...
# Doesn't have informations of version from https://www.thegioididong.com/thiet-bi-mang/router-wifi-chuan-ac1200-tp-link-archer-c64-gigabit
# Done item 2 / 60
# Starting item 3 / 60->Scraping...
# Doesn't have informations of version from https://www.thegioididong.com/thiet-bi-mang/router-wifi-chuan-wifi-6-ax1800-mercusys-archer-mr70x-den
# Done item 3 / 60
# Starting item 4 / 60->Scraping...
# Doesn't have informations of version from https://www.thegioididong.com/thiet-bi-mang/router-wifi-chuan-wifi-6-asus-tuf-gaming-ax4200
# Done item 4 / 60
# ...

# %%
error_items
# Out:
# ['https://www.thegioididong.com/thiet-bi-mang/usb-wifi-ac1200-asus-ac53-nano']

# %%
# %%time
file = "url_thiết_bị_thông_minh.txt"
items, error_items = scrape_data(file)
# Out:
# Starting item 0 / 37->Scraping...
# Doesn't have informations of version from https://www.thegioididong.com/camera-giam-sat/camera-ip-360-do-1080p-imou-ranger-2c-a22ep-l
# Done item 0 / 37
# Starting item 1 / 37->Scraping...
# Doesn't have informations of version from https://www.thegioididong.com/camera-giam-sat/camera-ip-360-do-1080p-ezviz-h6c
# Done item 1 / 37
# Starting item 2 / 37->Scraping...
# Doesn't have informations of version from https://www.thegioididong.com/camera-giam-sat/camera-trong-tre-1080p-ezviz-bm1
# Done item 2 / 37
# Starting item 3 / 37->Scraping...
# Doesn't have informations of version from https://www.thegioididong.com/camera-giam-sat/camera-ip-ngoai-troi-360-do-2mp-tp-link-tapo-c500
# Done item 3 / 37
# Starting item 4 / 37->Scraping...
# Doesn't have informations of version from https://www.thegioididong.com/may-chieu/may-chieu-wanbo-full-hd-tt-max
# Done item 4 / 37
# Starting item 5 / 37->Scraping...
# ...

# %%
error_items
# Out:
# ['https://www.thegioididong.com/may-chieu/viewsonic-m1-mini-plus',
#  'https://www.thegioididong.com/o-cam-thong-minh/dieu-khien-hong-ngoai-dien-quang-apollo-ir11-s',
#  'https://www.thegioididong.com/o-cam-thong-minh/o-cam-90-do-thong-minh-dien-quang-sps11-05-usb',
#  'https://www.thegioididong.com/o-cam-thong-minh/bong-den-thong-minh-87w-dimable-tp-link-tapo-l530e',
#  'https://www.thegioididong.com/o-cam-thong-minh/bong-den-thong-minh-87w-dimable-tp-link-tapo-l510e',
#  'https://www.thegioididong.com/o-cam-thong-minh/o-cam-dien-thong-minh-1-lo-tp-link-tapo-p100-trang']

# %%
# %%time
file = "url_sạc&cáp.txt"
items, error_items = scrape_data(file)
# Out:
# Starting item 0 / 236->Can't get features of item from https://www.thegioididong.com/adapter-sac/de-sac-khong-day-magsafe-3-in-1-15w-anker-737-cube-y1811
# Starting item 0 / 236->Can't get features of item from https://www.thegioididong.com/adapter-sac/adapter-sac-da-nang-universal-pd-65w-xmobile-ds636
# Starting item 0 / 236->Can't get features of item from https://www.thegioididong.com/adapter-sac/adapter-sac-2-cong-type-c-pd-gan-35w-mazer-gan35us
# Starting item 0 / 236->Scraping...
# Can't get features of item from https://www.thegioididong.com/cap-dien-thoai/cap-type-c-lightning-mfi-0-9m-anker-322-a81b5
# Starting item 0 / 236->

# %% [markdown]
# ## Save data

# %%
with open("data/thiết_bị_thông_minh.json", "w") as f:
    json.dump(items, f, ensure_ascii=True,indent=4)
